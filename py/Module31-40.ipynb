# %% [markdown]
# # Module31-40
# ## 20200901-20200905
#
# 1. matplotlib (绘图系统)
# 1. seaborn (绘图系统)
# 1. bokeh (绘图系统)
# 1. pyecharts (绘图系统)
# 1. ggplot (绘图系统)
# 1. geopandas (地理信息)
# 1. folium (地理信息)
# 1. sweetviz (EDA)
# 1. pandas_profiling (EDA)
# 1. redash (BI platform)

# %% [markdown]
# ### notin
# altair/lighting/plotly/holoviews

# %% [markdown]
# ### 4.31 matplotlib
#
# 1. 基本图形
#     1. 散点图
#     3. 线形图
#     2. 条形图
# 2. 图形处理

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
from IPython.display import IFrame

# %%
# %matplotlib inline

x = np.sort(np.random.rand(100),0)
#print(x)
y = np.random.rand(100)
plt.figure(3)
plt.scatter(x,y,marker='o')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
# %matplotlib inline

plt.figure(3)
plt.plot(x,y,marker='o',linestyle='-')
plt.xlim(-1,1)
plt.title('Line Plot')
# Out:
# Text(0.5, 1.0, 'Line plot')

# %%
# %matplotlib inline
cat = np.array(['a','b','c','d','e'])
x_index = np.array(range(5))
value1 = np.random.rand(5)*100
value2 = np.random.rand(5)*100
plt.figure(3)
plt.bar(x_index,value1,color='b',width=0.25)
plt.bar(x_index+0.25,value2,color='r',width=0.25)
plt.xticks(x_index + 0.25/2, cat)   
plt.title('Bar Plot')
# Out:
# Text(0.5, 1.0, 'Bar Plot')

# %%
# %matplotlib inline
x = np.random.rand(100)
plt.figure(3)
plt.hist(x)
plt.title('Hist Plot')
# Out:
# Text(0.5, 1.0, 'Hist Plot')

# %%
# %matplotlib inline

#使用numpy产生数据
x=np.arange(-5,5,0.1)
y=x*3

#创建窗口、子图
#方法1：先创建窗口，再创建子图。（一定绘制）
fig = plt.figure(num=1, figsize=(15, 8),dpi=80)     #开启一个窗口，同时设置大小，分辨率
ax1 = fig.add_subplot(2,1,1)  #通过fig添加子图，参数：行数，列数，第几个。
ax2 = fig.add_subplot(2,1,2)  #通过fig添加子图，参数：行数，列数，第几个。
print(fig,ax1,ax2)
#方法2：一次性创建窗口和多个子图。（空白不绘制）
fig,axarr = plt.subplots(4,1)  #开一个新窗口，并添加4个子图，返回子图数组
ax1 = axarr[0]    #通过子图数组获取一个子图
print(fig,ax1)
#方法3：一次性创建窗口和一个子图。（空白不绘制）
ax1 = plt.subplot(1,1,1,facecolor='white')      #开一个新窗口，创建1个子图。facecolor设置背景颜色
print(ax1)
#获取对窗口的引用，适用于上面三种方法
# fig = plt.gcf()   #获得当前figure
# fig=ax1.figure   #获得指定子图所属窗口

# fig.subplots_adjust(left=0)                         #设置窗口左内边距为0，即左边留白为0。

#设置子图的基本元素
ax1.set_title('python-drawing')            #设置图体，plt.title
ax1.set_xlabel('x-name')                    #设置x轴名称,plt.xlabel
ax1.set_ylabel('y-name')                    #设置y轴名称,plt.ylabel
plt.axis([-6,6,-10,10])                  #设置横纵坐标轴范围，这个在子图中被分解为下面两个函数
ax1.set_xlim(-5,5)                           #设置横轴范围，会覆盖上面的横坐标,plt.xlim
ax1.set_ylim(-10,10)                         #设置纵轴范围，会覆盖上面的纵坐标,plt.ylim

xmajorLocator = MultipleLocator(2)   #定义横向主刻度标签的刻度差为2的倍数。就是隔几个刻度才显示一个标签文本
ymajorLocator = MultipleLocator(3)   #定义纵向主刻度标签的刻度差为3的倍数。就是隔几个刻度才显示一个标签文本

ax1.xaxis.set_major_locator(xmajorLocator) #x轴 应用定义的横向主刻度格式。如果不应用将采用默认刻度格式
ax1.yaxis.set_major_locator(ymajorLocator) #y轴 应用定义的纵向主刻度格式。如果不应用将采用默认刻度格式

ax1.xaxis.grid(True, which='major')      #x坐标轴的网格使用定义的主刻度格式
ax1.yaxis.grid(True, which='major')      #x坐标轴的网格使用定义的主刻度格式

ax1.set_xticks([])     #去除坐标轴刻度
ax1.set_xticks((-5,-3,-1,1,3,5),['x1','x2','x3','x4','x5'])  #设置坐标轴刻度
#ax1.set_xticklabels(labels=['x1','x2','x3','x4','x5'],rotation=-30,fontsize='small')  #设置刻度的显示文本，rotation旋转角度，fontsize字体大小

plot1=ax1.plot(x,y,marker='o',color='g',label='legend1')   #点图：marker图标
plot2=ax1.plot(x,y,linestyle='--',alpha=0.5,color='r',label='legend2')   #线图：linestyle线性，alpha透明度，color颜色，label图例文本

ax1.legend(loc='upper left')            #显示图例,plt.legend()
ax1.text(2.8, 7, r'y=3*x')                #指定位置显示文字,plt.text()
ax1.annotate('important point', xy=(2, 6), xytext=(3, 1.5),  #添加标注，参数：注释文本、指向点、文字位置、箭头属性
            arrowprops=dict(facecolor='black', shrink=0.05),
            )
#显示网格。which参数的值为major(只绘制大刻度)、minor(只绘制小刻度)、both，默认值为major。axis为'x','y','both'
ax1.grid(b=True,which='major',axis='both',alpha= 0.5,color='skyblue',linestyle='--',linewidth=2)

axes1 = plt.axes([.2, .3, .1, .1], facecolor='y')       #在当前窗口添加一个子图，rect=[左, 下, 宽, 高]，是使用的绝对布局，不和以存在窗口挤占空间
axes1.plot(x,y)  #在子图上画图
plt.savefig('aa.jpg',dpi=400,bbox_inches='tight')   #savefig保存图片，dpi分辨率，bbox_inches子图周边白色空间的大小
plt.show()    #打开窗口，对于方法1创建在窗口一定绘制，对于方法2方法3创建的窗口，若坐标系全部空白，则不绘制
# Out:
# Figure(1200x640) AxesSubplot(0.125,0.536818;0.775x0.343182) AxesSubplot(0.125,0.125;0.775x0.343182)
# Figure(432x288) AxesSubplot(0.125,0.71587;0.775x0.16413)
# AxesSubplot(0.125,0.125;0.775x0.755)
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:44: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.

# %% [markdown]
# ---
# ### 4.32 seaborn
#
# seaborn的一个优势在于可以与pandas进行结合，基本绘图函数底层基于matplotlib，可以用matplotlib进行处理
#
# 1. 基本图形
#     1. relplot
#     3. distplot
#     2. catplot
#     4. pairplot
#
# 其他参考： http://seaborn.pydata.org/examples/index.html#example-gallery

# %%
IFrame('http://seaborn.pydata.org/examples/index.html#example-gallery', width=900, height=410)
# Out:
#         <iframe
#             width="900"
#             height="410"
#             src="http://seaborn.pydata.org/examples/index.html#example-gallery"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# %load

http://seaborn.pydata.org/examples/index.html#example-gallery
# Out:
#   File "<ipython-input-107-3c52ec19ebef>", line 3
#     http://seaborn.pydata.org/examples/index.html#example-gallery
#           ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns
import pandas as pd

# %%
x = np.arange(8)
y = np.array([1,5,3,6,2,4,5,6])

df = pd.DataFrame({"x": x,"y": y})

sns.barplot("x","y",palette="RdBu_r",data=df)
plt.xticks(rotation=90)
#plt.show()
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7')])

# %%
import random
f, axes = plt.subplots(2, 2, figsize=(17, 17), sharex=True)
sns.despine(left=True)
rs = np.random.RandomState(0)
d = np.random.normal(10,10,100)

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a historgram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])
# Out:
# <AxesSubplot:>

# %%
sns.set()
tips = sns.load_dataset("tips")
print(tips.head())
sns.relplot(x="total_bill", y="tip", col="time",
            #hue="smoker", 
            #style="smoker",
            #size="size",
            data=tips)

# %%
dots = sns.load_dataset("dots")
print(dots.head())
sns.relplot(x="time", y="firing_rate", col="align",
            hue="choice", size="coherence", style="choice",
            facet_kws=dict(sharex=False),
            kind="line", legend="full", data=dots);
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
fmri = sns.load_dataset("fmri")
print(fmri.head())
sns.relplot(x="timepoint", y="signal", col="region",
            hue="event",style="event",
            kind="line", data=fmri);
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lmplot(x="total_bill", y="tip", col="time", hue="smoker",
           data=tips);

# %%
sns.catplot(x="day", y="total_bill", hue="smoker",
            kind="swarm", data=tips);

# %%
sns.catplot(x="day", y="total_bill", hue="smoker",
            kind="violin", split=True, data=tips);

# %%
sns.catplot(x="day", y="total_bill", hue="smoker",
            kind="bar", data=tips);

# %%
f, axes = plt.subplots(1, 2, sharey=True, figsize=(6, 4))

sns.boxplot(x="day", y="tip", data=tips, ax=axes[0])
sns.scatterplot(x="total_bill", y="tip"
                #, hue="smoker"
                , data=tips, ax=axes[1]);

# %%
iris = sns.load_dataset("iris")
sns.jointplot(x="sepal_length", y="petal_length", data=iris);

# %%
sns.pairplot(data=iris, hue="species");

# %% [markdown]
# ---
# ### 4.33 bokeh
# 基本绘图包， 优势在于可以有交互效果和绑定鼠标事件

# %%
IFrame('https://demo.bokeh.org', width=900, height=410)
# Out:
#         <iframe
#             width="900"
#             height="410"
#             src="https://demo.bokeh.org"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from bokeh.plotting import figure 
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
from numpy import cos, linspace
x = linspace(-6, 6, 100)
y = cos(x)

# %%
p = figure(width=500, height=500)
p.circle(x, y, size=7, color="firebrick", alpha=0.5)
show(p)
# Out:
#   <div class="bk-root" id="550a84e0-d60b-402e-8ece-f1d0b037fe3f" data-root-id="1002"></div>

# %%
from bokeh.models import ColumnDataSource
from bokeh.layouts import gridplot

source = ColumnDataSource(autompg)

options = dict(plot_width=300, plot_height=300,
               tools="pan,wheel_zoom,box_zoom,box_select,lasso_select")

p1 = figure(title="MPG by Year", **options)
p1.circle("yr", "mpg", color="blue", source=source)

p2 = figure(title="HP vs. Displacement", **options)
p2.circle("hp", "displ", color="green", source=source)

p3 = figure(title="MPG vs. Displacement", **options)
p3.circle("mpg", "displ", size="cyl", line_color="red", fill_color=None, source=source)

p = gridplot([[ p1, p2, p3]], toolbar_location="right")

show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1b0893683236> in <module>
#       2 from bokeh.layouts import gridplot
#       3
# ----> 4 source = ColumnDataSource(autompg)
#       5
#       6 options = dict(plot_width=300, plot_height=300,
#
# NameError: name 'autompg' is not defined

# %% [markdown]
# ---
# ### 4.34 sweetviz
#
# ```sh
# jupyter labextension install jupyterlab-plotly@4.9.0
# ```

# %%
import sweetviz as sv
import seaborn as sns
iris = sns.load_dataset("iris")
my_report = sv.analyze(iris)
my_report.show_html() 
IFrame('./SWEETVIZ_REPORT.html', width=900, height=410)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#
# :FEATURES DONE:                    |█████████████████████| [100%]   00:01  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:00  -> (00:00 left)
# Creating Associations graph... DONE!
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: no browser will pop up, the report is saved in your notebook/colab files.
#         <iframe
#             width="900"
#             height="410"
#             src="./SWEETVIZ_REPORT.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
print(iris.head())
my_report = sv.analyze(iris,target_feat='sepal_length')
my_report.show_html()
IFrame('./SWEETVIZ_REPORT.html', width=900, height=410)
#target_feat
#my_report = sv.compare_intra(my_dataframe, my_dataframe["Sex"] == "male", ["Male", "Female"], feature_config)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#
#
#
#
#                                    |                         | [  0%]   00:00  -> (? left)
#
#
# Summarizing dataframe:             |                         | [  0%]   00:00  -> (? left)
#
#
# :TARGET::                          |███▌                 | [ 17%]   00:00  -> (00:00 left)
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# ...

# %% [markdown]
# ---
# ### 4.35 pyecharts
# py echarts接口
#
# - XXX() 选择数据
# - add_XXX 方式处理新增数据、设置
# - set_global_opts 基础设置

# %%
IFrame('https://gallery.pyecharts.org/#', width=900, height=410)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         <iframe
#             width="900"
#             height="410"
#             src="https://gallery.pyecharts.org/#"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.globals import CurrentConfig, NotebookType  
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB


# 不习惯链式调用的开发者依旧可以单独调用方法
bar = Bar()
bar.add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
bar.add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
bar.set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))
bar.render_notebook()
# Out:
# /usr/local/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="4ad56e7db57b4c49b0f89729e69a024c" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_4ad56e7db57b4c49b0f89729e69a024c = echarts.init(
#             document.getElementById('4ad56e7db57b4c49b0f89729e69a024c'), 'white', {renderer: 'canvas'});
#         var option_4ad56e7db57b4c49b0f89729e69a024c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
(
    Gauge(init_opts=opts.InitOpts(width="1600px", height="800px"))
    .add(series_name="业务指标", data_pair=[["完成率", 55.5]])
    .set_global_opts(
        legend_opts=opts.LegendOpts(is_show=False),
        tooltip_opts=opts.TooltipOpts(is_show=True, formatter="{a} <br/>{b} : {c}%"),
    )
    .render_notebook()
)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="371d632b047a4bb38c513e52aace2387" class="chart-container" style="width:1600px; height:800px;"></div>
#     <script>
#         var chart_371d632b047a4bb38c513e52aace2387 = echarts.init(
#             document.getElementById('371d632b047a4bb38c513e52aace2387'), 'white', {renderer: 'canvas'});
# ...

# %% [markdown]
# ---
# ### 4.36 ggplot
#  纯ggplot2语法，可执行列表如下：
#
# #### Plotting
# - [aesthetics](./plotting/aesthetics.ipynb)
# - [ggplot](./plotting/ggplot.ipynb)
# - [qplot](./plotting/qplot.ipynb)
#
# #### Geoms
# - [geom_abline](./geoms/geom_abline.ipynb)
# - [geom_area](./geoms/geom_area.ipynb)
# - [geom_bar](./geoms/geom_bar.ipynb)
# - [geom_bin2d](./geoms/geom_bin2d.ipynb)
# - [geom_blank](./geoms/geom_blank.ipynb)
# - [geom_boxplot](./geoms/geom_boxplot.ipynb)
# - [geom_density](./geoms/geom_density.ipynb)
# - [geom_histogram](./geoms/geom_histogram.ipynb)
# - [geom_hline](./geoms/geom_hline.ipynb)
# - [geom_jitter](./geoms/geom_jitter.ipynb)
# - [geom_line](./geoms/geom_line.ipynb)
# - [geom_point](./geoms/geom_point.ipynb)
# - [geom_rect](./geoms/geom_rect.ipynb)
# - [geom_ribbon](./geoms/geom_ribbon.ipynb)
# - [geom_step](./geoms/geom_step.ipynb)
# - [geom_text](./geoms/geom_text.ipynb)
# - [geom_tile](./geoms/geom_tile.ipynb)
# - [geom_vline](./geoms/geom_vline.ipynb)
#
# #### Stats
# - [stat_density](./stats/stat_density.ipynb)
# - [stat_smooth](./stats/stat_smooth.ipynb)
#
# #### Facets
# - [facet_grid](./facets/facet_grid.ipynb)
# - [facet_wrap](./facets/facet_wrap.ipynb)
#
# #### Scales
# - [scale_alpha_identity](./scales/scale_alpha_identity.ipynb)
# - [scale_color_brewer](./scales/scale_color_brewer.ipynb)
# - [scale_color_crayon](./scales/scale_color_crayon.ipynb)
# - [scale_color_funfetti](./scales/scale_color_funfetti.ipynb)
# - [scale_color_gradient](./scales/scale_color_gradient.ipynb)
# - [scale_color_identity](./scales/scale_color_identity.ipynb)
# - [scale_color_manual](./scales/scale_color_manual.ipynb)
# - [scale_fill_identity](./scales/scale_fill_identity.ipynb)
# - [scale_linetype_identity](./scales/scale_linetype_identity.ipynb)
# - [scale_x_continuous](./scales/scale_x_continuous.ipynb)
# - [scale_x_date](./scales/scale_x_date.ipynb)
# - [scale_x_discrete](./scales/scale_x_discrete.ipynb)
# - [scale_x_log](./scales/scale_x_log.ipynb)
# - [scale_x_reverse](./scales/scale_x_reverse.ipynb)
# - [scale_y_continuous](./scales/scale_y_continuous.ipynb)
# - [scale_y_log](./scales/scale_y_log.ipynb)
# - [scale_y_reverse](./scales/scale_y_reverse.ipynb)
#
# bugfix:
#
# ```
# cd /usr/local/lib/python3.7/site-packages/ggplot
# pd.tslib.Timestamp 改为 pd.Timestamp
#
# cd stat
# vi smoothers.py
# #from pandas.lib import Timestamp
# from pandas import Timestamp
# pd.tslib.Timestamp 改为 pd.Timestamp
# ```

# %%
from ggplot import *
ggplot(mtcars, aes(x='wt' ,y='mpg')) +geom_point()
# Out:
# <ggplot: (8782831781405)>

# %% [markdown]
# ---
# ### 4.37 ~~basemap~~ redash
# redash dv platform

# %%
IFrame('http://data.wm-motor.cn:443', width=900, height=410)
# Out:
#         <iframe
#             width="900"
#             height="410"
#             src="http://data.wm-motor.cn:443"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ---
# ### 4.38 geopandas

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
# %matplotlib inline

world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
print(world.head())
world.plot()
plt.show()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# ...

# %%
world.boundary.plot();
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.

# %%
world.plot(column='pop_est', legend=True)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# <AxesSubplot:>

# %%
world.plot(column='pop_est', legend=True, cmap='OrRd')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# <AxesSubplot:>

# %% [markdown]
# ---
# ### 4.39 folium
#
# leaflet相关包

# %%
import folium
m = folium.Map(location=[31.2, 121.2],
                          zoom_start=10,
            tiles='http://webrd02.is.autonavi.com/appmaptile?lang=zh_cn&size=1&scale=1&style=7&x={x}&y={y}&z={z}',
            attr='default')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Map=folium.Map(location=[34.1194,108.8342],
            zoom_start=14,
            tiles='http://webrd02.is.autonavi.com/appmaptile?lang=zh_cn&size=1&scale=1&style=7&x={x}&y={y}&z={z}',
            attr='default'
        )

folium.Marker([34.1194,108.8342],
              popup=folium.Popup('西安电子科技大学',max_width=1000),
              tooltip='click here'
             ).add_to(Map)

folium.Polygon([
    [34.527832,108.361311],
    [34.527834,108.361302],
    [34.527836,108.361306]
]).add_to(Map)

folium.PolyLine([
    [34.527832,108.361311],
    [34.527834,108.361302],
    [34.527836,108.361306]
],color='green').add_to(Map)

folium.Circle([34.1194,108.8342]
              , 500
              ,color='red'
              ,fill_color='red'
              ,fillOpacity=0.5
             ).add_to(Map)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---
# ### 4.40 ~~networkx~~

# %% [markdown]
# ---
# ### 4.40 pandas_profiling

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

profile = ProfileReport(iris, title="Pandas Profiling Report")
profile
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# ...

# %%
import matplotlib.pyplot as plt
import networkx as nx

G = nx.grid_2d_graph(5, 5)  # 5x5 grid

# print the adjacency list
for line in nx.generate_adjlist(G):
    print(line)
# write edgelist to grid.edgelist
nx.write_edgelist(G, path="grid.edgelist", delimiter=":")
# read edgelist from grid.edgelist
H = nx.read_edgelist(path="grid.edgelist", delimiter=":")

nx.draw(H)
plt.show()
# Out:
# /usr/local/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /usr/local/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# (0, 0) (1, 0) (0, 1)
# (0, 1) (1, 1) (0, 2)
# (0, 2) (1, 2) (0, 3)
# (0, 3) (1, 3) (0, 4)
# (0, 4) (1, 4)
# (1, 0) (2, 0) (1, 1)
# (1, 1) (2, 1) (1, 2)
# (1, 2) (2, 2) (1, 3)
# (1, 3) (2, 3) (1, 4)
# (1, 4) (2, 4)
# (2, 0) (3, 0) (2, 1)
# (2, 1) (3, 1) (2, 2)
# (2, 2) (3, 2) (2, 3)
# (2, 3) (3, 3) (2, 4)
# (2, 4) (3, 4)
# (3, 0) (4, 0) (3, 1)
# (3, 1) (4, 1) (3, 2)
# (3, 2) (4, 2) (3, 3)
# (3, 3) (4, 3) (3, 4)
# (3, 4) (4, 4)
# (4, 0) (4, 1)
# (4, 1) (4, 2)
# (4, 2) (4, 3)
# (4, 3) (4, 4)
# (4, 4)
